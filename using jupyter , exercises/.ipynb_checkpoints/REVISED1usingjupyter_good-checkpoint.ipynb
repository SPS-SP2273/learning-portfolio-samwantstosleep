# %% [markdown]
# # Exercise 1 (learning to interrupt)

# %%
while True:
    print('*', end='')
    #this prints like crazy. fortunately there's a stop button in the taskbar. yay i stopped it woohoo :D
    #then press the kernel button and find the restart option
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %% [markdown]
# # Exercise 2 (resetting and restarting the kernel. i get it now :D)

# %%
print = 'PRINT'
print('Hello World')

#i don't get what this exercise does. before restarting this thing didn't even print anything
#but after restarting i get a TypeError: 'str' object is not callable

#with hindsight, need to put these on different code lines then run them

# %%
'''To gain a better understanding of this exercise, try following these steps:

1) Make a code cell with print('Hello World')

2) Make a code cell with print = 'PRINT'

3) Make a code cell with print('Hello World')

4) Run in order 1-3, you should get the error above at 3

5) Restart kernel and run 3

OOH I GET IT NOW IT'S JUST TEACHING ME THAT SOME PROBLEMS CAN BE SOLVED BY RESTARTING KERNEL THANKS

# %%
print('Hellooooooo')
# Out:
# Hellooooooo

# %%
print = 'PRINT'

# %%
print('Gday mate')
# Out:
# Gday mate
